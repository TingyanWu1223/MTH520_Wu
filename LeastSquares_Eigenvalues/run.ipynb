# %%
import lstsq_eigs
import numpy as np
m, n = 8, 3
A = np.random.randn(m, n)
x_true = np.arange(1, n+1)
b = A @ x_true
x_est = lstsq_eigs.least_squares(A, b)

print("Estimated x:", np.round(x_est, 4))
# Out:
# Estimated x: [1. 2. 3.]

# %%
lstsq_eigs.line_fit()

# %%
lstsq_eigs.polynomial_fit()
